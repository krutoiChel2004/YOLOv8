# %%
# pip install opencv-python
# pip install ultralytics

# %%
import cv2
import os
from ultralytics import YOLO

# %%
model = YOLO('C:/Users/качёк/Desktop/DRONE PROJECT GTA/script_V2/runs/detect/train/weight/best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\dataset\Recaptch_factory-1.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/dataset/Recaptch_factory-1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> model = YOLO('C:/Users/качёк/Desktop/DRONE PROJECT GTA/script_V2/runs/detect/train/weight/best.pt')
#
# File d:\anaconda3\lib\site-packages\ultralytics\engine\model.py:92, in Model.__init__(self, model, task)
#      90     self._new(model, task)
#      91 else:
# ---> 92     self._load(model, task)
#
# File d:\anaconda3\lib\site-packages\ultralytics\engine\model.py:137, in Model._load(self, weights, task)
#     135 suffix = Path(weights).suffix
#     136 if suffix == '.pt':
# --> 137     self.model, self.ckpt = attempt_load_one_weight(weights)
#     138     self.task = self.model.args['task']
# ...

# %%
def delete_files_in_folder(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file_name in files:
            file_path = os.path.join(root, file_name)
            try:
                os.unlink(file_path)
            except Exception as e:
                print(f"Error deleting file: {file_path} -- {e}")

# %%
directory = r"C:\\Users\\качёк\\Videos\\frame"
train_images_path = 'C:\\Users\\качёк\\Videos\\Annotat_frame\\img'
img_list = os.listdir(directory)
print(f"В папке имеется {len(img_list)} изображений")
# Out:
# В папке имеется 9254 изображений

# %%
# delete_files_in_folder('imgbase/train/images')
# delete_files_in_folder('imgbase/train/labels')

# %%
for img_name in img_list:
    img_filepath = directory +"\\"+ img_name
    print(img_filepath)
    img = cv2.imread(img_filepath)
    img_copy = img
    
    # предобработка изображения как перед обучением
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # gray_three = cv2.merge([gray,gray,gray])
    # img = gray_three
    
    # получаем ширину и высоту картинки
    h, w, _ = img.shape
    
    # получаем предсказания по картинке
    results = model.predict(source=img, conf=0.20)
    
    # расшифровываем объект results
    bboxes_ = results[0].boxes.xyxy.tolist()
    bboxes = list(map(lambda x: list(map(lambda y: int(y), x)), bboxes_))
    confs_ = results[0].boxes.conf.tolist()
    confs = list(map(lambda x: int(x*100), confs_))
    classes_ = results[0].boxes.cls.tolist()
    classes = list(map(lambda x: int(x), classes_))
    cls_dict = results[0].names
    class_names = list(map(lambda x: cls_dict[x], classes))
    
    # приводим дешифрированные данные в удобный вид
    annot_lines = []
    for index, val in enumerate(class_names):
        xmin, ymin, xmax, ymax = int(bboxes[index][0]), int(bboxes[index][1]), int(bboxes[index][2]), int(bboxes[index][3])
        width = xmax - xmin
        height = ymax - ymin
        center_x = xmin + (width/2)
        center_y = ymin + (height/2) 
        annotation = f"{classes[index]} {center_x/w} {center_y/h} {width/w} {height/h}"
        annot_lines.append(annotation)
    
    # копируем картинку в папку базы изображений для импорта
    cv2.imwrite(os.path.join(train_images_path , img_name), img_copy)
    
    # записываем файл аннотации в папку базы изображений для импорта
    txt_name = img_name.replace(".jpg",".txt")
    with open(f'C:\\Users\\качёк\\Videos\\Annotat_frame\\labels\\{txt_name}', 'w') as f:
        for line in annot_lines:
            f.write(line)
            f.write('\n')
# Out:
# 0: 384x640 1 person, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# C:\\Users\\качёк\\Videos\\frame\Grand Theft Auto V 2023.10.08 - 01.25.11.01_000001.jpg
# C:\\Users\\качёк\\Videos\\frame\Grand Theft Auto V 2023.10.08 - 01.25.11.01_000002.jpg
# 0: 384x640 1 person, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.0ms
# C:\\Users\\качёк\\Videos\\frame\Grand Theft Auto V 2023.10.08 - 01.25.11.01_000003.jpg
# C:\\Users\\качёк\\Videos\\frame\Grand Theft Auto V 2023.10.08 - 01.25.11.01_000004.jpg
# C:\\Users\\качёк\\Videos\\frame\Grand Theft Auto V 2023.10.08 - 01.25.11.01_000005.jpg
# ...
